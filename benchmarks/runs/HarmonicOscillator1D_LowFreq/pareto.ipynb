# %%
import numpy as np
import matplotlib.pyplot as plt
import os
from benchmarks.runs.exploring_utils import RunAnalyser, adaptive_filter, non_adaptive_filter, model_filter

# %%
run_path = '../'
test_name = 'HarmonicOscillator1D_LowFreq'
test_path = os.path.join(run_path, test_name)

# %%
runs = sorted([m for m in os.listdir(test_path) if os.path.isdir(os.path.join(test_path, m))])
analyser = RunAnalyser(runs, test_path)

# %%
analyser.plot_mse_over_params(legend=False)

# %% [markdown]
# ckan8 is most optimal

# %%
analyser.plot_mse_over_flops( legend=False)

# %%
analyser.plot_training_times()

# %%
analyser.plot_mse_over_params(filter=lambda x: 'CKAN' in x or 'FCN' in x)

# %%
f = lambda x: x in [
    'CKAN_8',
    'CKAN_16',
    'CKAN_32',
    'StackedCKAN_d4_h2',
    'StackedCKAN_d4_h4',
    'FCN_8',
    'FCN_32',
    'FCN_(8, 8)',
    'FCN_(32, 32)',
]
analyser.plot_mse_over_params(filter=f)

# %%
analyser.plot_mse_over_flops(filter=f)
