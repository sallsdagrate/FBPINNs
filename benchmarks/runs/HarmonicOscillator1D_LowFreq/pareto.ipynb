# %%
import numpy as np
import matplotlib.pyplot as plt
import os
from benchmarks.runs.exploring_utils import RunAnalyser, adaptive_filter, non_adaptive_filter, model_filter

# %%
run_path = '../'
test_name = 'HarmonicOscillator1D_LowFreq'
test_path = os.path.join(run_path, test_name)

# %%
runs = sorted([m for m in os.listdir(test_path) if os.path.isdir(os.path.join(test_path, m))])
analyser = RunAnalyser(runs, test_path)

# %%
analyser.plot_mse_over_params()
# Out:
# /vol/bitbucket/ss7921/FBPINNs/benchmarks/runs/exploring_utils.py:145: UserWarning: No data for colormapping provided via 'c'. Parameters 'cmap' will be ignored
#   plt.scatter(params, mse, label=model, cmap='viridis')

# %% [markdown]
# ckan8 is most optimal

# %%
analyser.plot_mse_over_flops()

# %%
analyser.plot_mse_over_params()

# %%
# import numpy as np
# import pandas as pd
# import seaborn as sns
# import matplotlib.pyplot as plt

# # 1) generate some fake 2D data
# np.random.seed(0)
# X = np.random.randn(200, 2)

# # 2) a simple Pareto‐ranking function
# def pareto_ranks(points):
#     n = points.shape[0]
#     ranks = np.zeros(n, dtype=int)
#     for i in range(n):
#         # count how many points strictly dominate point i
#         dominates = np.all(points <= points[i], axis=1) & np.any(points < points[i], axis=1)
#         ranks[i] = np.sum(dominates) + 1
#     return ranks

# ranks = pareto_ranks(X)

# # 3) build a DataFrame
# df = pd.DataFrame({
#     "x": X[:,0],
#     "y": X[:,1],
#     "pareto_rank": ranks
# })

# # 4) plot with Seaborn
# plt.figure(figsize=(6,5))
# sns.scatterplot(
#     data=df,
#     x="x", y="y",
#     hue="pareto_rank",                 # map colour → rank
#     palette="viridis",                 # any matplotlib colormap
#     hue_norm=(df.pareto_rank.min(),    # normalize so colour spans min→max rank
#               df.pareto_rank.max()),
#     legend="full",                     # show all discrete ranks in legend
#     s=60,                              # point size
#     edgecolor="w"                      # white border for clarity
# )
# plt.title("Scatterplot colored by Pareto rank")
# plt.xlabel("X")
# plt.ylabel("Y")
# plt.tight_layout()
# plt.show()
# Out:
# /tmp/ipykernel_1397478/3518306347.py:45: UserWarning: Tight layout not applied. The bottom and top margins cannot be made large enough to accommodate all Axes decorations.
#   plt.tight_layout()
