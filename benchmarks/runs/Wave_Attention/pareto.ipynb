# %%
import numpy as np
import matplotlib.pyplot as plt
import os
from benchmarks.runs.exploring_utils import RunAnalyser, adaptive_filter, non_adaptive_filter, model_filter
import re

# %%
run_path = '../'
test_name = 'Wave_Attention'
test_path = os.path.join(run_path, test_name)

# %%
runs = sorted([m for m in os.listdir(test_path) if os.path.isdir(os.path.join(test_path, m))])
analyser = RunAnalyser(runs, test_path)

# %%
analyser.plot_mse_over_params()

# %%
analyser.plot_mse_over_flops()

# %%
analyser.plot_training_times(filter=lambda x: 'Stacked' in x or 'FCN' in x)

# %%
analyser.plot_mses()

# %%
analyser.runs
# Out:
# ['FCN_[32, 32]',
#  'FCN_[8, 8]',
#  'StackedJacobiKAN__deg[6, 6]_h[4]',
#  'StackedJacobiKAN__deg[6, 6]_h[8]',
#  'StackedLegendreKAN__deg[4, 4]_h[4]',
#  'StackedLegendreKAN__deg[4, 4]_h[8]']

# %%
names = ['Wave_Attention', 'Wave_200']

models = ['FCN_[32, 32]']
for model in models:
    for name in names:
        test_name_ = name
        test_path_ = os.path.join(run_path, test_name_)
        runs_ = sorted([m for m in os.listdir(test_path_) if os.path.isdir(os.path.join(test_path_, m))])
        analyser_ = RunAnalyser(runs_, test_path_)

        analyser_.plot_mses(lambda x: x == model, noshow=True)
    plt.legend()
    plt.show()
