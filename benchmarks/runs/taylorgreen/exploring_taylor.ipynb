# %%
import numpy as np
import matplotlib.pyplot as plt
import os
from benchmarks.runs.exploring_utils import RunAnalyser, adaptive_filter, non_adaptive_filter, model_filter
import re

# %%
run_path = '../'
test_name = 'taylorgreen'

test_path = os.path.join(run_path, test_name)

# %%
late_stage = 8000

# %%
runs = sorted([m for m in os.listdir(test_path) if os.path.isdir(os.path.join(test_path, m))])
runs
# Out:
# ['FCN_[16, 16]',
#  'FCN_[32, 32]',
#  'FCN_[4, 4]',
#  'FCN_[8, 8]',
#  'OptimizedStackedCKAN_deg[4, 4]_h[5]',
#  'OptimizedStackedCKAN_deg[4, 4]_h[6]',
#  'OptimizedStackedCKAN_deg[5, 5]_h[4]',
#  'OptimizedStackedCKAN_deg[6, 6]_h[4]',
#  'OptimizedStackedCKAN_deg[7, 7]_h[4]',
#  'StackedCKAN_deg[4, 4]_h[1]',
#  'StackedCKAN_deg[4, 4]_h[2]',
#  'StackedCKAN_deg[4, 4]_h[3]',
#  'StackedCKAN_deg[4, 4]_h[4]']

# %%
analyser = RunAnalyser(runs, test_path)

# %%
# Plot all models
analyser.plot_mses()

# %%
analyser.plot_mses(filter=lambda x: re.match('(Optimized)*StackedCKAN_deg\[4, 4]_h\[[0-9]]', x))
# Out:
# <>:1: SyntaxWarning: invalid escape sequence '\['
# <>:1: SyntaxWarning: invalid escape sequence '\['
# /tmp/ipykernel_1684389/2651866585.py:1: SyntaxWarning: invalid escape sequence '\['
#   analyser.plot_mses(filter=lambda x: re.match('(Optimized)*StackedCKAN_deg\[4, 4]_h\[[0-9]]', x))
