# %%
import numpy as np
import matplotlib.pyplot as plt
import os
from benchmarks.runs.exploring_utils import RunAnalyser, adaptive_filter, non_adaptive_filter, model_filter
import re

# %%
run_path = '../'
test_name = 'Kovasznay'
test_path = os.path.join(run_path, test_name)

# %%
runs = sorted([m for m in os.listdir(test_path) if os.path.isdir(os.path.join(test_path, m))])
analyser = RunAnalyser(runs, test_path)

# %%
analyser.plot_mse_over_params()

# %%
analyser.plot_mse_over_flops()

# %%
analyser.plot_training_times(filter=lambda x: 'Stacked' in x or 'FCN' in x)

# %%
# analyser.plot_mse_over_params(filter=lambda x: 'StackedCKAN_deg[' in x and ']_h[4]' in x, )
analyser.plot_mse_over_params(filter=lambda x: re.match('(Optimized)*Stacked[C|L]KAN_deg[4[, 4]*]_h[4[, 4]*]', x), title='Change in layers')

# %%
analyser.plot_mse_over_params(filter=lambda x: re.match('Stacked[C|L]KAN_deg\[4, 4]_h\[[0-9]*]', x) or 'FCN_[32' in x, title='Change in hidden dimensions')
# Out:
# <>:1: SyntaxWarning: invalid escape sequence '\['
# <>:1: SyntaxWarning: invalid escape sequence '\['
# /tmp/ipykernel_3565638/1776983630.py:1: SyntaxWarning: invalid escape sequence '\['
#   analyser.plot_mse_over_params(filter=lambda x: re.match('Stacked[C|L]KAN_deg\[4, 4]_h\[[0-9]*]', x) or 'FCN_[32' in x, title='Change in hidden dimensions')

# %%
analyser.plot_mse_over_params(filter=lambda x: re.match('StackedCKAN_deg\[[0-9]*, 4]_h\[4]', x), title='Change in in-degrees')
# Out:
# <>:1: SyntaxWarning: invalid escape sequence '\['
# <>:1: SyntaxWarning: invalid escape sequence '\['
# /tmp/ipykernel_3565638/3581135910.py:1: SyntaxWarning: invalid escape sequence '\['
#   analyser.plot_mse_over_params(filter=lambda x: re.match('StackedCKAN_deg\[[0-9]*, 4]_h\[4]', x), title='Change in in-degrees')

# %%
analyser.plot_mse_over_params(filter=lambda x: re.match('StackedCKAN_deg\[4, [0-9]*]_h\[4]', x), title='Change in out-degrees')
# Out:
# <>:1: SyntaxWarning: invalid escape sequence '\['
# <>:1: SyntaxWarning: invalid escape sequence '\['
# /tmp/ipykernel_3565638/4165519912.py:1: SyntaxWarning: invalid escape sequence '\['
#   analyser.plot_mse_over_params(filter=lambda x: re.match('StackedCKAN_deg\[4, [0-9]*]_h\[4]', x), title='Change in out-degrees')

# %%
analyser.plot_mse_over_flops(filter=lambda x: re.match('(Optimized)*Stacked[C|L]KAN_deg[4[, 4]*]_h[4[, 4]*]', x), title='Change in layers')
